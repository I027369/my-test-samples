# %%
pip install tensorflow
# Out:
# Collecting tensorflow
#   Downloading https://files.pythonhosted.org/packages/7b/61/743150d9cf5e028ac5cdd694ea26968a37ae054728c9d290c72c2687a982/tensorflow-2.4.1-cp37-cp37m-macosx_10_11_x86_64.whl (173.9MB)
#      |████████████████████████████████| 173.9MB 247kB/s eta 0:00:011
# Collecting astunparse~=1.6.3 (from tensorflow)
#   Using cached https://files.pythonhosted.org/packages/2b/03/13dde6512ad7b4557eb792fbcf0c653af6076b81e5941d36ec61f7ce6028/astunparse-1.6.3-py2.py3-none-any.whl
# Collecting google-pasta~=0.2 (from tensorflow)
#   Using cached https://files.pythonhosted.org/packages/a3/de/c648ef6835192e6e2cc03f40b19eeda4382c49b5bafb43d88b931c4c74ac/google_pasta-0.2.0-py3-none-any.whl
# Collecting termcolor~=1.1.0 (from tensorflow)
#   Using cached https://files.pythonhosted.org/packages/8a/48/a76be51647d0eb9f10e2a4511bf3ffb8cc1e6b14e9e4fab46173aa79f981/termcolor-1.1.0.tar.gz
# Collecting tensorboard~=2.4 (from tensorflow)
#   Downloading https://files.pythonhosted.org/packages/64/21/eebd23060763fedeefb78bc2b286e00fa1d8abda6f70efa2ee08c28af0d4/tensorboard-2.4.1-py3-none-any.whl (10.6MB)
#      |████████████████████████████████| 10.6MB 8.2MB/s eta 0:00:01
# Collecting numpy~=1.19.2 (from tensorflow)
#   Downloading https://files.pythonhosted.org/packages/39/ba/f3db2b5bb36fee2478b1cf47e7f9664b9c27241be80acd31c844404da297/numpy-1.19.5-cp37-cp37m-macosx_10_9_x86_64.whl (15.6MB)
#      |████████████████████████████████| 15.6MB 18.7MB/s eta 0:00:01
# Collecting six~=1.15.0 (from tensorflow)
#   Using cached https://files.pythonhosted.org/packages/ee/ff/48bde5c0f013094d729fe4b0316ba2a24774b3ff1c52d924a8a4cb04078a/six-1.15.0-py2.py3-none-any.whl
# Collecting gast==0.3.3 (from tensorflow)
#   Using cached https://files.pythonhosted.org/packages/d6/84/759f5dd23fec8ba71952d97bcc7e2c9d7d63bdc582421f3cd4be845f0c98/gast-0.3.3-py2.py3-none-any.whl
# Collecting absl-py~=0.10 (from tensorflow)
#   Using cached https://files.pythonhosted.org/packages/bc/58/0aa6fb779dc69cfc811df3398fcbeaeefbf18561b6e36b185df0782781cc/absl_py-0.11.0-py3-none-any.whl
# Collecting typing-extensions~=3.7.4 (from tensorflow)
#   Using cached https://files.pythonhosted.org/packages/60/7a/e881b5abb54db0e6e671ab088d079c57ce54e8a01a3ca443f561ccadb37e/typing_extensions-3.7.4.3-py3-none-any.whl
# Collecting wheel~=0.35 (from tensorflow)
#   Using cached https://files.pythonhosted.org/packages/65/63/39d04c74222770ed1589c0eaba06c05891801219272420b40311cd60c880/wheel-0.36.2-py2.py3-none-any.whl
# Collecting flatbuffers~=1.12.0 (from tensorflow)
#   Using cached https://files.pythonhosted.org/packages/eb/26/712e578c5f14e26ae3314c39a1bdc4eb2ec2f4ddc89b708cf8e0a0d20423/flatbuffers-1.12-py2.py3-none-any.whl
# Collecting wrapt~=1.12.1 (from tensorflow)
#   Using cached https://files.pythonhosted.org/packages/82/f7/e43cefbe88c5fd371f4cf0cf5eb3feccd07515af9fd6cf7dbf1d1793a797/wrapt-1.12.1.tar.gz
# Collecting opt-einsum~=3.3.0 (from tensorflow)
#   Using cached https://files.pythonhosted.org/packages/bc/19/404708a7e54ad2798907210462fd950c3442ea51acc8790f3da48d2bee8b/opt_einsum-3.3.0-py3-none-any.whl
# Collecting h5py~=2.10.0 (from tensorflow)
#   Downloading https://files.pythonhosted.org/packages/1a/8b/4d01ae9a9d50a0bcc7b0b9aae41785d8d9de6fa9bba04dc20b1582181d2d/h5py-2.10.0-cp37-cp37m-macosx_10_6_intel.whl (3.0MB)
#      |████████████████████████████████| 3.0MB 17.7MB/s eta 0:00:01
# Collecting grpcio~=1.32.0 (from tensorflow)
#   Downloading https://files.pythonhosted.org/packages/48/16/d229a9d7d45bafecfe6b4c9ebf2053ec929efc2ffbed0b1a89ef190ef4d9/grpcio-1.32.0-cp37-cp37m-macosx_10_9_x86_64.whl (3.3MB)
#      |████████████████████████████████| 3.3MB 9.9MB/s eta 0:00:01
# Collecting protobuf>=3.9.2 (from tensorflow)
#   Downloading https://files.pythonhosted.org/packages/fd/38/dc1b4ec33d3ebd540f2410c14743d3dc24f9df6556fde8c13983a9ba2a0a/protobuf-3.14.0-cp37-cp37m-macosx_10_9_x86_64.whl (1.0MB)
#      |████████████████████████████████| 1.0MB 11.5MB/s eta 0:00:01
# Collecting tensorflow-estimator<2.5.0,>=2.4.0 (from tensorflow)
#   Using cached https://files.pythonhosted.org/packages/74/7e/622d9849abf3afb81e482ffc170758742e392ee129ce1540611199a59237/tensorflow_estimator-2.4.0-py2.py3-none-any.whl
# Collecting keras-preprocessing~=1.1.2 (from tensorflow)
#   Using cached https://files.pythonhosted.org/packages/79/4c/7c3275a01e12ef9368a892926ab932b33bb13d55794881e3573482b378a7/Keras_Preprocessing-1.1.2-py2.py3-none-any.whl
# Collecting tensorboard-plugin-wit>=1.6.0 (from tensorboard~=2.4->tensorflow)
#   Downloading https://files.pythonhosted.org/packages/1a/c1/499e600ba0c618b451cd9c425ae1c177249940a2086316552fee7d86c954/tensorboard_plugin_wit-1.8.0-py3-none-any.whl (781kB)
#      |████████████████████████████████| 788kB 5.4MB/s eta 0:00:01
# Collecting markdown>=2.6.8 (from tensorboard~=2.4->tensorflow)
#   Using cached https://files.pythonhosted.org/packages/ac/ef/24a91ca96efa0d7802dffb83ccc7a3c677027bea19ec3c9ee80be740408e/Markdown-3.3.3-py3-none-any.whl
# Collecting google-auth<2,>=1.6.3 (from tensorboard~=2.4->tensorflow)
#   Using cached https://files.pythonhosted.org/packages/3e/fd/df1b3a59aca9537a187413651ad63b290d165559150a868a298fa837fe7b/google_auth-1.24.0-py2.py3-none-any.whl
# Collecting google-auth-oauthlib<0.5,>=0.4.1 (from tensorboard~=2.4->tensorflow)
#   Using cached https://files.pythonhosted.org/packages/81/67/e2c34bb0628984c7ce71cce6ba6964cb29c418873847fc285f826e032e6e/google_auth_oauthlib-0.4.2-py2.py3-none-any.whl
# Requirement already satisfied: requests<3,>=2.21.0 in /Users/i027369/opt/anaconda3/lib/python3.7/site-packages (from tensorboard~=2.4->tensorflow) (2.22.0)
# Requirement already satisfied: werkzeug>=0.11.15 in /Users/i027369/opt/anaconda3/lib/python3.7/site-packages (from tensorboard~=2.4->tensorflow) (0.16.0)
# Requirement already satisfied: setuptools>=41.0.0 in /Users/i027369/opt/anaconda3/lib/python3.7/site-packages (from tensorboard~=2.4->tensorflow) (41.4.0)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /Users/i027369/opt/anaconda3/lib/python3.7/site-packages (from markdown>=2.6.8->tensorboard~=2.4->tensorflow) (0.23)
# Collecting cachetools<5.0,>=2.0.0 (from google-auth<2,>=1.6.3->tensorboard~=2.4->tensorflow)
#   Using cached https://files.pythonhosted.org/packages/92/da/d3c94fc7c72ad9298072681ec3e8cea86949acc5c4cce4290ba21f7050a8/cachetools-4.2.0-py3-none-any.whl
# Collecting rsa<5,>=3.1.4; python_version >= "3.6" (from google-auth<2,>=1.6.3->tensorboard~=2.4->tensorflow)
#   Downloading https://files.pythonhosted.org/packages/bf/87/dc7a6ebf0afbc602548627fa48e9c1147fa187233bf71d4c51c76a2cfb27/rsa-4.7-py3-none-any.whl
# Collecting pyasn1-modules>=0.2.1 (from google-auth<2,>=1.6.3->tensorboard~=2.4->tensorflow)
#   Using cached https://files.pythonhosted.org/packages/95/de/214830a981892a3e286c3794f41ae67a4495df1108c3da8a9f62159b9a9d/pyasn1_modules-0.2.8-py2.py3-none-any.whl
# Collecting requests-oauthlib>=0.7.0 (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.4->tensorflow)
#   Using cached https://files.pythonhosted.org/packages/a3/12/b92740d845ab62ea4edf04d2f4164d82532b5a0b03836d4d4e71c6f3d379/requests_oauthlib-1.3.0-py2.py3-none-any.whl
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /Users/i027369/opt/anaconda3/lib/python3.7/site-packages (from requests<3,>=2.21.0->tensorboard~=2.4->tensorflow) (1.24.2)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /Users/i027369/opt/anaconda3/lib/python3.7/site-packages (from requests<3,>=2.21.0->tensorboard~=2.4->tensorflow) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/i027369/opt/anaconda3/lib/python3.7/site-packages (from requests<3,>=2.21.0->tensorboard~=2.4->tensorflow) (2019.9.11)
# Requirement already satisfied: idna<2.9,>=2.5 in /Users/i027369/opt/anaconda3/lib/python3.7/site-packages (from requests<3,>=2.21.0->tensorboard~=2.4->tensorflow) (2.8)
# Requirement already satisfied: zipp>=0.5 in /Users/i027369/opt/anaconda3/lib/python3.7/site-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tensorboard~=2.4->tensorflow) (0.6.0)
# Collecting pyasn1>=0.1.3 (from rsa<5,>=3.1.4; python_version >= "3.6"->google-auth<2,>=1.6.3->tensorboard~=2.4->tensorflow)
#   Using cached https://files.pythonhosted.org/packages/62/1e/a94a8d635fa3ce4cfc7f506003548d0a2447ae76fd5ca53932970fe3053f/pyasn1-0.4.8-py2.py3-none-any.whl
# Collecting oauthlib>=3.0.0 (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.4->tensorflow)
#   Using cached https://files.pythonhosted.org/packages/05/57/ce2e7a8fa7c0afb54a0581b14a65b56e62b5759dbc98e80627142b8a3704/oauthlib-3.1.0-py2.py3-none-any.whl
# Requirement already satisfied: more-itertools in /Users/i027369/opt/anaconda3/lib/python3.7/site-packages (from zipp>=0.5->importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tensorboard~=2.4->tensorflow) (7.2.0)
# Building wheels for collected packages: termcolor, wrapt
#   Building wheel for termcolor (setup.py) ... done
#   Created wheel for termcolor: filename=termcolor-1.1.0-cp37-none-any.whl size=4832 sha256=287cbd2beecc3cdaf92fdc0e297cf72a80302353e6fda629ff2d8a69850401fd
#   Stored in directory: /Users/i027369/Library/Caches/pip/wheels/7c/06/54/bc84598ba1daf8f970247f550b175aaaee85f68b4b0c5ab2c6
#   Building wheel for wrapt (setup.py) ... done
#   Created wheel for wrapt: filename=wrapt-1.12.1-cp37-cp37m-macosx_10_9_x86_64.whl size=32422 sha256=3ee7b1e96e5206569ffb2e084e1cca9c2d25b41c849eaebd188c46781ebfb517
#   Stored in directory: /Users/i027369/Library/Caches/pip/wheels/b1/c2/ed/d62208260edbd3fa7156545c00ef966f45f2063d0a84f8208a
# Successfully built termcolor wrapt
# ERROR: astroid 2.3.1 requires typed-ast<1.5,>=1.4.0; implementation_name == "cpython" and python_version < "3.8", which is not installed.
# ERROR: astroid 2.3.1 has requirement six==1.12, but you'll have six 1.15.0 which is incompatible.
# ERROR: astroid 2.3.1 has requirement wrapt==1.11.*, but you'll have wrapt 1.12.1 which is incompatible.
# Installing collected packages: six, wheel, astunparse, google-pasta, termcolor, tensorboard-plugin-wit, absl-py, markdown, cachetools, pyasn1, rsa, pyasn1-modules, google-auth, oauthlib, requests-oauthlib, google-auth-oauthlib, numpy, grpcio, protobuf, tensorboard, gast, typing-extensions, flatbuffers, wrapt, opt-einsum, h5py, tensorflow-estimator, keras-preprocessing, tensorflow
#   Found existing installation: six 1.12.0
#     Uninstalling six-1.12.0:
#       Successfully uninstalled six-1.12.0
#   Found existing installation: wheel 0.33.6
#     Uninstalling wheel-0.33.6:
#       Successfully uninstalled wheel-0.33.6
#   Found existing installation: numpy 1.17.2
#     Uninstalling numpy-1.17.2:
#       Successfully uninstalled numpy-1.17.2
#   Found existing installation: wrapt 1.11.2
#     Uninstalling wrapt-1.11.2:
#       Successfully uninstalled wrapt-1.11.2
#   Found existing installation: h5py 2.9.0
#     Uninstalling h5py-2.9.0:
#       Successfully uninstalled h5py-2.9.0
# Successfully installed absl-py-0.11.0 astunparse-1.6.3 cachetools-4.2.0 flatbuffers-1.12 gast-0.3.3 google-auth-1.24.0 google-auth-oauthlib-0.4.2 google-pasta-0.2.0 grpcio-1.32.0 h5py-2.10.0 keras-preprocessing-1.1.2 markdown-3.3.3 numpy-1.19.5 oauthlib-3.1.0 opt-einsum-3.3.0 protobuf-3.14.0 pyasn1-0.4.8 pyasn1-modules-0.2.8 requests-oauthlib-1.3.0 rsa-4.7 six-1.15.0 tensorboard-2.4.1 tensorboard-plugin-wit-1.8.0 tensorflow-2.4.1 tensorflow-estimator-2.4.0 termcolor-1.1.0 typing-extensions-3.7.4.3 wheel-0.36.2 wrapt-1.12.1
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn import datasets
import numpy as np
import tensorflow as tf

# %%
def _ohe(targets):
    y = np.zeros((150, 3))
    for i, label in enumerate(targets):
        y[i, label] = 1.0
    return y

# %%
def train(X, y, epochs, batch_size=16):
    model = tf.keras.Sequential([
        tf.keras.layers.InputLayer(input_shape=(4,)),
        tf.keras.layers.Dense(16, activation=tf.nn.relu),
        tf.keras.layers.Dense(16, activation=tf.nn.relu),
        tf.keras.layers.Dense(3, activation='softmax')
    ])
    model.compile(tf.keras.optimizers.RMSprop(learning_rate=0.001), loss='categorical_crossentropy', metrics=['accuracy'])
    model.fit(X, y, epochs=epochs)
    return model

# %%
def freeze(model, path='../frozen'):
    model.save(f'{path}/0001')
    return True

# %%
if __name__ == '__main__':
    iris = datasets.load_iris()
    X, targets = iris.data, iris.target
    y = _ohe(targets)
    model = train(X, y, epochs=50)
    freeze(model)
# Out:
# Epoch 1/50
# 5/5 [==============================] - 0s 959us/step - loss: 1.0216 - accuracy: 0.3335
# Epoch 2/50
# 5/5 [==============================] - 0s 1ms/step - loss: 0.9331 - accuracy: 0.6387
# Epoch 3/50
# 5/5 [==============================] - 0s 1ms/step - loss: 0.9215 - accuracy: 0.6266
# Epoch 4/50
# 5/5 [==============================] - 0s 2ms/step - loss: 0.8827 - accuracy: 0.6775
# Epoch 5/50
# 5/5 [==============================] - 0s 1ms/step - loss: 0.8700 - accuracy: 0.6558
# Epoch 6/50
# 5/5 [==============================] - 0s 1ms/step - loss: 0.8456 - accuracy: 0.6597
# Epoch 7/50
# 5/5 [==============================] - 0s 1ms/step - loss: 0.8157 - accuracy: 0.6762
# Epoch 8/50
# 5/5 [==============================] - 0s 2ms/step - loss: 0.8162 - accuracy: 0.6440
# Epoch 9/50
# 5/5 [==============================] - 0s 1ms/step - loss: 0.7840 - accuracy: 0.6530
# Epoch 10/50
# 5/5 [==============================] - 0s 2ms/step - loss: 0.7836 - accuracy: 0.6292
# Epoch 11/50
# 5/5 [==============================] - 0s 2ms/step - loss: 0.7509 - accuracy: 0.6215
# Epoch 12/50
# 5/5 [==============================] - 0s 1ms/step - loss: 0.7584 - accuracy: 0.5968
# Epoch 13/50
# 5/5 [==============================] - 0s 2ms/step - loss: 0.7372 - accuracy: 0.6465
# Epoch 14/50
# 5/5 [==============================] - 0s 2ms/step - loss: 0.7367 - accuracy: 0.6435
# Epoch 15/50
# 5/5 [==============================] - 0s 2ms/step - loss: 0.7211 - accuracy: 0.6575
# Epoch 16/50
# 5/5 [==============================] - 0s 1ms/step - loss: 0.6900 - accuracy: 0.6827
# Epoch 17/50
# 5/5 [==============================] - 0s 2ms/step - loss: 0.6749 - accuracy: 0.6540
# Epoch 18/50
# 5/5 [==============================] - 0s 2ms/step - loss: 0.6821 - accuracy: 0.6166
# Epoch 19/50
# 5/5 [==============================] - 0s 1ms/step - loss: 0.6645 - accuracy: 0.6162
# Epoch 20/50
# 5/5 [==============================] - 0s 1ms/step - loss: 0.6331 - accuracy: 0.6836
# Epoch 21/50
# 5/5 [==============================] - 0s 2ms/step - loss: 0.6592 - accuracy: 0.6424
# Epoch 22/50
# 5/5 [==============================] - 0s 1ms/step - loss: 0.6127 - accuracy: 0.6710
# Epoch 23/50
# 5/5 [==============================] - 0s 2ms/step - loss: 0.6147 - accuracy: 0.6775
# Epoch 24/50
# 5/5 [==============================] - 0s 2ms/step - loss: 0.6277 - accuracy: 0.6267
# Epoch 25/50
# 5/5 [==============================] - 0s 2ms/step - loss: 0.5891 - accuracy: 0.6836
# Epoch 26/50
# 5/5 [==============================] - 0s 2ms/step - loss: 0.5875 - accuracy: 0.6636
# Epoch 27/50
# 5/5 [==============================] - 0s 1ms/step - loss: 0.5933 - accuracy: 0.6645
# Epoch 28/50
# 5/5 [==============================] - 0s 2ms/step - loss: 0.5757 - accuracy: 0.6684
# Epoch 29/50
# 5/5 [==============================] - 0s 1ms/step - loss: 0.5796 - accuracy: 0.6363
# Epoch 30/50
# 5/5 [==============================] - 0s 2ms/step - loss: 0.5711 - accuracy: 0.6063
# Epoch 31/50
# 5/5 [==============================] - 0s 2ms/step - loss: 0.5334 - accuracy: 0.6719
# Epoch 32/50
# 5/5 [==============================] - 0s 2ms/step - loss: 0.5604 - accuracy: 0.6437
# Epoch 33/50
# 5/5 [==============================] - 0s 2ms/step - loss: 0.5372 - accuracy: 0.6528
# Epoch 34/50
# 5/5 [==============================] - 0s 1ms/step - loss: 0.5316 - accuracy: 0.6437
# Epoch 35/50
# 5/5 [==============================] - 0s 1ms/step - loss: 0.5430 - accuracy: 0.6285
# Epoch 36/50
# 5/5 [==============================] - 0s 2ms/step - loss: 0.4981 - accuracy: 0.6693
# Epoch 37/50
# 5/5 [==============================] - 0s 2ms/step - loss: 0.5206 - accuracy: 0.6480
# Epoch 38/50
# 5/5 [==============================] - 0s 2ms/step - loss: 0.4991 - accuracy: 0.6823
# Epoch 39/50
# 5/5 [==============================] - 0s 2ms/step - loss: 0.4651 - accuracy: 0.6962
# Epoch 40/50
# 5/5 [==============================] - 0s 2ms/step - loss: 0.4867 - accuracy: 0.6510
# Epoch 41/50
# 5/5 [==============================] - 0s 2ms/step - loss: 0.4763 - accuracy: 0.6671
# Epoch 42/50
# 5/5 [==============================] - 0s 2ms/step - loss: 0.4521 - accuracy: 0.6940
# Epoch 43/50
# 5/5 [==============================] - 0s 1ms/step - loss: 0.4604 - accuracy: 0.6780
# Epoch 44/50
# 5/5 [==============================] - 0s 2ms/step - loss: 0.4290 - accuracy: 0.7270
# Epoch 45/50
# 5/5 [==============================] - 0s 2ms/step - loss: 0.4453 - accuracy: 0.7249
# Epoch 46/50
# 5/5 [==============================] - 0s 2ms/step - loss: 0.4498 - accuracy: 0.7019
# Epoch 47/50
# 5/5 [==============================] - 0s 2ms/step - loss: 0.4445 - accuracy: 0.7474
# Epoch 48/50
# 5/5 [==============================] - 0s 2ms/step - loss: 0.4401 - accuracy: 0.7513
# Epoch 49/50
# 5/5 [==============================] - 0s 1ms/step - loss: 0.4603 - accuracy: 0.7714
# Epoch 50/50
# 5/5 [==============================] - 0s 2ms/step - loss: 0.4558 - accuracy: 0.7446
# INFO:tensorflow:Assets written to: ../frozen/0001/assets
